# %%
from ultralytics import YOLO
model = YOLO(r"J:\AI based welding detection in Gas metal arc welding\weldingpoolposition\n_scratch\weights\best.pt")
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.209  Python-3.11.5 torch-2.1.0+cpu CPU (Intel Core(TM) i5-2400 3.10GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3077975 parameters, 0 gradients, 8.3 GFLOPs
#
# PyTorch: starting from 'J:\AI based welding detection in Gas metal arc welding\weldingpoolposition\n_scratch\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 17, 8400) (6.1 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#   Obtaining dependency information for onnx>=1.12.0 from https://files.pythonhosted.org/packages/db/2d/0851d7bb5ae1d08cc27a0ccfba9e77e2393f47ea56e57d347e2926b6d316/onnx-1.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 14.3/14.3 MB 59.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success  35.4s, installed 1 package: ['onnx>=1.12.0']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ...

# %%
import onnx
onnx_model = onnx.load('J:\\AI based welding detection in Gas metal arc welding\\weldingpoolposition\\n_scratch\\weights\\best.onnx')
onnx.checker.check_model(onnx_model)

# %%
print(onnx.helper.printable_graph(onnx_model.graph))
# Out:
# graph main_graph (
#   %images[FLOAT, 1x3x640x640]
# ) initializers (
#   %model.0.conv.weight[FLOAT, 16x3x3x3]
#   %model.0.conv.bias[FLOAT, 16]
#   %model.1.conv.weight[FLOAT, 32x16x3x3]
#   %model.1.conv.bias[FLOAT, 32]
#   %model.2.cv1.conv.weight[FLOAT, 32x32x1x1]
#   %model.2.cv1.conv.bias[FLOAT, 32]
#   %model.2.cv2.conv.weight[FLOAT, 32x48x1x1]
#   %model.2.cv2.conv.bias[FLOAT, 32]
#   %model.2.m.0.cv1.conv.weight[FLOAT, 16x16x3x3]
#   %model.2.m.0.cv1.conv.bias[FLOAT, 16]
#   %model.2.m.0.cv2.conv.weight[FLOAT, 16x16x3x3]
#   %model.2.m.0.cv2.conv.bias[FLOAT, 16]
#   %model.3.conv.weight[FLOAT, 64x32x3x3]
#   %model.3.conv.bias[FLOAT, 64]
#   %model.4.cv1.conv.weight[FLOAT, 64x64x1x1]
#   %model.4.cv1.conv.bias[FLOAT, 64]
#   %model.4.cv2.conv.weight[FLOAT, 64x128x1x1]
#   %model.4.cv2.conv.bias[FLOAT, 64]
#   %model.4.m.0.cv1.conv.weight[FLOAT, 32x32x3x3]
#   %model.4.m.0.cv1.conv.bias[FLOAT, 32]
#   %model.4.m.0.cv2.conv.weight[FLOAT, 32x32x3x3]
# ...

# %%
from ultralytics import YOLO
model = YOLO(r"J:\AI based image processing for the detection of process features in Gas Metal Arc Welding\Weldingpool_keypoints\n_model7\weights\best.pt")
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.209  Python-3.11.5 torch-2.1.0+cpu CPU (Intel Core(TM) i5-2400 3.10GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3077975 parameters, 0 gradients, 8.3 GFLOPs
#
# PyTorch: starting from 'J:\AI based image processing for the detection of process features in Gas Metal Arc Welding\Weldingpool_keypoints\n_model7\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 17, 8400) (6.1 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success  2.2s, saved as 'J:\AI based image processing for the detection of process features in Gas Metal Arc Welding\Weldingpool_keypoints\n_model7\weights\best.onnx' (12.1 MB)
#
# Export complete (9.9s)
# Results saved to \\han.isf.rwth-aachen.de\home\bib-ya\AI based image processing for the detection of process features in Gas Metal Arc Welding\Weldingpool_keypoints\n_model7\weights
# ...
