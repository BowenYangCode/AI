# %%
# !pip install wandb

# %%
wandb login
# Out:
#   Cell In[4], line 1
#     wandb login
#           ^
# SyntaxError: invalid syntax

# %%
# !yolo pose train data=welding.yaml model=yolov8n-pose.pt project=Weldingpool_keypointstest name=n_scratch epochs=50 batch=8 device=cpu
# Out:
# New https://pypi.org/project/ultralytics/8.1.2 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209  Python-3.11.5 torch-2.1.0+cpu CPU (Intel Core(TM) i5-2400 3.10GHz)
# ...

# %%
python your_training_script.py --data path/to/Triangle_215.yaml
# Out:
#   Cell In[13], line 1
#     python your_training_script.py --data path/to/Triangle_215.yaml
#            ^
# SyntaxError: invalid syntax

# %%
# Linux or macOS
find . -name "yolov8*"

# Windows (PowerShell)
Get-ChildItem -Recurse -Filter "yolov8*" | Select-Object FullName
# Out:
#   Cell In[14], line 2
#     find . -name "yolov8*"
#            ^
# SyntaxError: invalid syntax

# %%
# !rm -rf datasets/Triangle_215_Keypoint_YOLO.zip datasets/Triangle_215_Keypoint_YOLO
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215_Keypoint_YOLO.zip
# Out:
# Der Befehl "rm" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
# !pip install wget

# %%
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# Out:
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# Out:
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
wandb login
# Out:
#   Cell In[1], line 1
#     wandb login
#           ^
# SyntaxError: invalid syntax

# %%
# !yolo pose train data=weldingpool.yaml model=yolov8n-pose.pt project=Weldingpool_keypoints name=n_model epochs=100 batch=16 device=cpu
# Out:
# New https://pypi.org/project/ultralytics/8.1.1 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209  Python-3.11.5 torch-2.1.0+cpu CPU (Intel Core(TM) i5-2400 3.10GHz)
# ...

# %%
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# Out:
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
import wget

# %%
# !wget https://zihao-download.obs.cn-east-3.myhuaweicloud.com/yolov8/datasets/Triangle_215_Dataset/Triangle_215.yaml
# Out:
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
# !yolo pose train data=weldingpool.yaml model=yolov8m-pose.pt project=Weldingpool_keypoints name=m_model epochs=100 batch=16 device=cpu
# Out:
# ^C
