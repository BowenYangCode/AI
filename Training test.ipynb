# %%
# !yolo pose train data=weldingpool.yaml model=yolov8n-pose.pt project=weldingpoolposition name=n_scratch epochs=50 batch=16 device=cpu
# Out:
# New https://pypi.org/project/ultralytics/8.0.215 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209  Python-3.11.5 torch-2.1.0+cpu CPU (Intel Core(TM) i5-2400 3.10GHz)
# ...

# %%
# !yolo pose train data=weldingpool.yaml model=yolov8m-pose.pt project=weldingpoolposition name=m_scratch epochs=50 batch=16 device=cpu
# Out:
# ^C
