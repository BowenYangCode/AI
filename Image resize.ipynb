# %%
import cv2
import os

# %% [markdown]
# # Set the input and output directories

# %%
input_dir = ""
output_dir = "J:\AI based welding detection in Gas metal arc welding\Resized image"

# %% [markdown]
# # Set the desired dimensions for resizing

# %%
desired_width = 640
desired_height = 640

# %% [markdown]
# # Loop through the images in the input directory

# %%
for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):  # Adjust the file formats as needed
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))

        # Resize the image
        resized_img = cv2.resize(img, (desired_width, desired_height))

        # Save the resized image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), resized_img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 7
#       4 img = cv2.imread(os.path.join(input_dir, filename))
#       6 # Resize the image
# ----> 7 resized_img = cv2.resize(img, (desired_width, desired_height))
#       9 # Save the resized image to the output directory
#      10 cv2.imwrite(os.path.join(output_dir, filename), resized_img)
#
# error: OpenCV(4.6.0) C:\b\abs_f8n1j3l9l0\croot\opencv-suite_1691622637237\work\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
import cv2
import os

input_dir = "J:\Bowen Images\imagetotal"
output_dir = "J:\Bowen Images\Resized image1"

for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        img = cv2.imread(os.path.join(input_dir, filename))

        if img is not None and img.size > 0:  # Check if the image is valid
            desired_width = 640
            desired_height = 640
            resized_img = cv2.resize(img, (desired_width, desired_height))
            cv2.imwrite(os.path.join(output_dir, filename), resized_img)
        else:
            print(f"Invalid image: {filename}")

# %%
import cv2
import os

input_dir = r"J:\slag detection\image"
output_dir = r"J:\slag detection\640-480image"

for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        img = cv2.imread(os.path.join(input_dir, filename))

        if img is not None and img.size > 0:  # Check if the image is valid
            desired_width = 640
            desired_height = 480
            resized_img = cv2.resize(img, (desired_width, desired_height))
            cv2.imwrite(os.path.join(output_dir, filename), resized_img)
        else:
            print(f"Invalid image: {filename}")

# %%
from PIL import Image
import os

def resize_images(input_folder, output_folder, new_size):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        # Check if the file is an image
        if os.path.isfile(input_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif')):
            # Open the image
            img = Image.open(input_path)

            # Resize the image
            img_resized = img.resize(new_size)

            # Save the resized image to the output folder
            img_resized.save(output_path)

            print(f"Resized: {filename}")

if __name__ == "__main__":
    # Set your input and output folders
    input_folder = "J:\weld pool images_bib\V6"
    output_folder = "J:\weld pool images_bib\resizedV6"

    # Set the new size (width, height)
    new_size = (500, 500)

    # Resize images
    resize_images(input_folder, output_folder, new_size)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 36
#      33 new_size = (500, 500)
#      35 # Resize images
# ---> 36 resize_images(input_folder, output_folder, new_size)
#
# Cell In[4], line 7, in resize_images(input_folder, output_folder, new_size)
#       4 def resize_images(input_folder, output_folder, new_size):
#       5     # Create the output folder if it doesn't exist
#       6     if not os.path.exists(output_folder):
# ----> 7         os.makedirs(output_folder)
#       9     # Loop through all files in the input folder
#      10     for filename in os.listdir(input_folder):
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [WinError 123] Die Syntax für den Dateinamen, Verzeichnisnamen oder die Datenträgerbezeichnung ist falsch: 'J:\\weld pool images_bib\resizedV6'

# %%
import cv2
import os

input_dir = r"J:\weld pool images_bib\V6"
output_dir = r"J:\weld pool images_bib\resizedV6"

# Ensure the output directory exists
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))

        # Check if the image is valid
        if img is not None and img.size > 0:
            # Set the desired width and height
            desired_width = 500
            desired_height = 500

            # Resize the image
            resized_img = cv2.resize(img, (desired_width, desired_height))

            # Save the resized image
            cv2.imwrite(os.path.join(output_dir, filename), resized_img)
        else:
            print(f"Invalid image: {filename}")
# Out:
# Invalid image: 1.png
# Invalid image: 10.png
# Invalid image: 104.png
# Invalid image: 105.png
# Invalid image: 12.png
# Invalid image: 121.png
# Invalid image: 123.png
# Invalid image: 124.png
# Invalid image: 127.png
# Invalid image: 131.png
# Invalid image: 132.png
# Invalid image: 133.png
# Invalid image: 134.png
# Invalid image: 135.png
# Invalid image: 136.png
# Invalid image: 144.png
# Invalid image: 145.png
# Invalid image: 148.png
# Invalid image: 149.png
# Invalid image: 15.png
# Invalid image: 152.png
# Invalid image: 153.png
# Invalid image: 154.png
# Invalid image: 155.png
# Invalid image: 160.png
# Invalid image: 165.png
# Invalid image: 166.png
# Invalid image: 168.png
# Invalid image: 170.png
# Invalid image: 171.png
# Invalid image: 172.png
# Invalid image: 186.png
# Invalid image: 187.png
# Invalid image: 192.png
# Invalid image: 193.png
# Invalid image: 196.png
# Invalid image: 20.png
# Invalid image: 208.png
# Invalid image: 21.png
# Invalid image: 211.png
# ...
